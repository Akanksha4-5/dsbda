# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("data2.csv")

# %%
df
# Out:
#    gender  math score reading score  writing score  Placement Score  \
# 0  female        72.0            74           78.0              1.0
# 1  female        69.0            90           88.0              NaN
# 2  female        90.0            95           93.0             74.0
# 3    male        47.0            57            NaN             78.0
# 4    male         NaN            78           75.0             81.0
# 5  female        71.0            Na           78.0             70.0
# 6    male        12.0            44           52.0             12.0
# 7    male         NaN            65           67.0             49.0
# 8    male         5.0            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df.isnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0   False       False          False          False            False
# 1   False       False          False          False             True
# 2   False       False          False          False            False
# 3   False       False          False           True            False
# 4   False        True          False          False            False
# 5   False       False          False          False            False
# 6   False       False          False          False            False
# 7   False        True          False          False            False
# 8   False       False          False          False            False
#
#    placement offer count  Region
# 0                  False   False
# 1                  False   False
# 2                  False   False
# 3                  False   False
# 4                  False   False
# 5                  False   False
# 6                  False   False
# 7                  False   False
# 8                  False    True

# %%
series = pd.isnull(df["math score"])
df[series]
# Out:
#   gender  math score reading score  writing score  Placement Score  \
# 4   male         NaN            78           75.0             81.0
# 7   male         NaN            65           67.0             49.0
#
#    placement offer count Region
# 4                      3   Pune
# 7                      1   Pune

# %%
df.notnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0    True        True           True           True             True
# 1    True        True           True           True            False
# 2    True        True           True           True             True
# 3    True        True           True          False             True
# 4    True       False           True           True             True
# 5    True        True           True           True             True
# 6    True        True           True           True             True
# 7    True       False           True           True             True
# 8    True        True           True           True             True
#
#    placement offer count  Region
# 0                   True    True
# 1                   True    True
# 2                   True    True
# 3                   True    True
# 4                   True    True
# 5                   True    True
# 6                   True    True
# 7                   True    True
# 8                   True   False

# %%
series1 = pd.notnull(df["math score"])
df[series1]
# Out:
#    gender  math score reading score  writing score  Placement Score  \
# 0  female        72.0            74           78.0              1.0
# 1  female        69.0            90           88.0              NaN
# 2  female        90.0            95           93.0             74.0
# 3    male        47.0            57            NaN             78.0
# 5  female        71.0            Na           78.0             70.0
# 6    male        12.0            44           52.0             12.0
# 8    male         5.0            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 5                      4      na
# 6                      2  Nashik
# 8                      0     NaN

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])
newdf=df
df
# Out:
#    gender  math score reading score  writing score  Placement Score  \
# 0       0        72.0            74           78.0              1.0
# 1       0        69.0            90           88.0              NaN
# 2       0        90.0            95           93.0             74.0
# 3       1        47.0            57            NaN             78.0
# 4       1         NaN            78           75.0             81.0
# 5       0        71.0            Na           78.0             70.0
# 6       1        12.0            44           52.0             12.0
# 7       1         NaN            65           67.0             49.0
# 8       1         5.0            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df
# Out:
#    gender  math score reading score  writing score  Placement Score  \
# 0       0        72.0            74           78.0              1.0
# 1       0        69.0            90           88.0              NaN
# 2       0        90.0            95           93.0             74.0
# 3       1        47.0            57            NaN             78.0
# 4       1         NaN            78           75.0             81.0
# 5       0        71.0            Na           78.0             70.0
# 6       1        12.0            44           52.0             12.0
# 7       1         NaN            65           67.0             49.0
# 8       1         5.0            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
missing_values = ["Na", "na"," "]
df = pd.read_csv("data2.csv", na_values = missing_values)
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           74.0           78.0              1.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
ndf=df
ndf.fillna(0)
ndf
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           74.0           78.0              1.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df['reading score'] = df['reading score'].fillna(df['reading score'].median())
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           74.0           78.0              1.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0           75.5           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df['math score'] = df['math score'].fillna(df['math score'].mean())
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0           78.0              1.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# 4    male   52.285714           78.0           75.0             81.0
# 5  female   71.000000           75.5           78.0             70.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
# 8    male    5.000000           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df['writing score'] = df['writing score'].fillna(df['writing score'].std())
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0      78.000000              1.0
# 1  female   69.000000           90.0      88.000000              NaN
# 2  female   90.000000           95.0      93.000000             74.0
# 3    male   47.000000           57.0      13.363062             78.0
# 4    male   52.285714           78.0      75.000000             81.0
# 5  female   71.000000           75.5      78.000000             70.0
# 6    male   12.000000           44.0      52.000000             12.0
# 7    male   52.285714           65.0      67.000000             49.0
# 8    male    5.000000           77.0      89.000000             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df['Placement Score'] = df['Placement Score'].fillna(df['Placement Score'].min())
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0      78.000000              1.0
# 1  female   69.000000           90.0      88.000000              1.0
# 2  female   90.000000           95.0      93.000000             74.0
# 3    male   47.000000           57.0      13.363062             78.0
# 4    male   52.285714           78.0      75.000000             81.0
# 5  female   71.000000           75.5      78.000000             70.0
# 6    male   12.000000           44.0      52.000000             12.0
# 7    male   52.285714           65.0      67.000000             49.0
# 8    male    5.000000           77.0      89.000000             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0      78.000000              1.0
# 1  female   69.000000           90.0      88.000000              1.0
# 2  female   90.000000           95.0      93.000000             74.0
# 3    male   47.000000           57.0      13.363062             78.0
# 4    male   52.285714           78.0      75.000000             81.0
# 5  female   71.000000           75.5      78.000000             70.0
# 6    male   12.000000           44.0      52.000000             12.0
# 7    male   52.285714           65.0      67.000000             49.0
# 8    male    5.000000           77.0      89.000000             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0      78.000000              1.0
# 1  female   69.000000           90.0      88.000000              1.0
# 2  female   90.000000           95.0      93.000000             74.0
# 3    male   47.000000           57.0      13.363062             78.0
# 4    male   52.285714           78.0      75.000000             81.0
# 5  female   71.000000           75.5      78.000000             70.0
# 6    male   12.000000           44.0      52.000000             12.0
# 7    male   52.285714           65.0      67.000000             49.0
# 8    male    5.000000           77.0      89.000000             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     -99
# 2                      2  Nashik
# 3                      1     -99
# 4                      3    Pune
# 5                      4     -99
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     -99

# %%
ndf.dropna()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0           78.0              1.0
# 2  female   90.000000           95.0           93.0             74.0
# 4    male   52.285714           78.0           75.0             81.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
#
#    placement offer count  Region
# 0                      1    Pune
# 2                      2  Nashik
# 4                      3    Pune
# 6                      2  Nashik
# 7                      1    Pune

# %%
ndf.dropna(how = 'all')
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0      78.000000              1.0
# 1  female   69.000000           90.0      88.000000              1.0
# 2  female   90.000000           95.0      93.000000             74.0
# 3    male   47.000000           57.0      13.363062             78.0
# 4    male   52.285714           78.0      75.000000             81.0
# 5  female   71.000000           75.5      78.000000             70.0
# 6    male   12.000000           44.0      52.000000             12.0
# 7    male   52.285714           65.0      67.000000             49.0
# 8    male    5.000000           77.0      89.000000             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
ndf.dropna(axis = 1)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0      78.000000              1.0
# 1  female   69.000000           90.0      88.000000              1.0
# 2  female   90.000000           95.0      93.000000             74.0
# 3    male   47.000000           57.0      13.363062             78.0
# 4    male   52.285714           78.0      75.000000             81.0
# 5  female   71.000000           75.5      78.000000             70.0
# 6    male   12.000000           44.0      52.000000             12.0
# 7    male   52.285714           65.0      67.000000             49.0
# 8    male    5.000000           77.0      89.000000             55.0
#
#    placement offer count
# 0                      1
# 1                      2
# 2                      2
# 3                      1
# 4                      3
# 5                      4
# 6                      2
# 7                      1
# 8                      0

# %%
new_data = ndf.dropna(axis = 0, how ='any')
new_data
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           74.0           78.0              1.0
# 2  female   90.000000           95.0           93.0             74.0
# 4    male   52.285714           78.0           75.0             81.0
# 6    male   12.000000           44.0           52.0             12.0
# 7    male   52.285714           65.0           67.0             49.0
#
#    placement offer count  Region
# 0                      1    Pune
# 2                      2  Nashik
# 4                      3    Pune
# 6                      2  Nashik
# 7                      1    Pune

# %%
df=pd.read_csv("data2.csv")
df
# Out:
#    gender  math score reading score  writing score  Placement Score  \
# 0  female        72.0            74           78.0              1.0
# 1  female        69.0            90           88.0              NaN
# 2  female        90.0            95           93.0             74.0
# 3    male        47.0            57            NaN             78.0
# 4    male         NaN            78           75.0             81.0
# 5  female        71.0            Na           78.0             70.0
# 6    male        12.0            44           52.0             12.0
# 7    male         NaN            65           67.0             49.0
# 8    male         5.0            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df['reading score'] = pd.to_numeric(df['reading score'], errors='coerce')
df['writing score'] = pd.to_numeric(df['writing score'], errors='coerce')
df['math score'] = pd.to_numeric(df['math score'], errors='coerce')

# %%
print(np.where(df['math score']>90))
print(np.where(df['reading score']<25))
print(np.where(df['writing score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score']))

# %%
print(z)
# Out:
# [nan nan nan nan nan nan nan nan nan]

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([], dtype=int64),)

# %%
sorted_rscore= sorted(df['reading score'])
sorted_rscore
# Out:
# ['44', '57', '65', '74', '77', '78', '90', '95', 'Na']

# %%
sorted_rscore = np.sort(df['reading score'].dropna())

q1 = np.percentile(sorted_rscore, 25)

print(q1)
# Out:
# 63.0

# %%
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 62.0 74.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 44.0 92.0

# %%
r_outliers = []
for i in sorted_rscore:
  if (i<lwr_bound or i>upr_bound):
    r_outliers.append(i)
  print(r_outliers)
# Out:
# [1]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16]
# [1, 16, 120]
